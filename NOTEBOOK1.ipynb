# %% [markdown]
# <a href="https://colab.research.google.com/github/JxseMG30/Programacion_Computadores/blob/main/NOTEBOOK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CONTENIDOS
# EFGH3EWLDH,D,JQDH,KQWHD,WQHD,Q

# %% [markdown]
# 1. TODAS LAS ECUACIONES EN FORMATO LATEX SE ENCUENTRAN EN EL SIGUIENTE LINK
# [APUNTES DE LATEX](https://metodos.fam.cie.uva.es/~latex/apuntes/apuntes3.pdf)
